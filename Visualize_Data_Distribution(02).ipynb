# %% [markdown]
# <a href="https://colab.research.google.com/github/Suchirapon/data_viz/blob/main/Visualize_Data_Distribution(02).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## การแสดงผลการกระจายของข้อมูล
#
# ### scatter พิจารณาข้อมูลเป็นจุด
#
# ### scatter 3D

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# ### scatter - default
#
# มองข้อมูลเป็นจุดแล้วเอามาเทียบ

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'])

# %% [markdown]
# # color

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],c='r')

# %% [markdown]
# ## ใส่สีให้แต่ละจุด

# %%
set(df['Name']) # set ยุบรวมว่ามีค่าอะไรบ้าง
# Out:
# {'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'}

# %%
df2 = df.replace({'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica':2}) #เปลี่ยนตัวอักษรให้เป็นตัวเลข
df2
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth  Name
# 0            5.1         3.5          1.4         0.2     0
# 1            4.9         3.0          1.4         0.2     0
# 2            4.7         3.2          1.3         0.2     0
# 3            4.6         3.1          1.5         0.2     0
# 4            5.0         3.6          1.4         0.2     0
# ..           ...         ...          ...         ...   ...
# 145          6.7         3.0          5.2         2.3     2
# 146          6.3         2.5          5.0         1.9     2
# 147          6.5         3.0          5.2         2.0     2
# 148          6.2         3.4          5.4         2.3     2
# 149          5.9         3.0          5.1         1.8     2
#
# [150 rows x 5 columns]

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],c=df2['Name'])

# %% [markdown]
# ## _alpha_ กำหนดความโปร่งแสง

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],c=df2['Name'],alpha=0.5)

# %% [markdown]
# ## _marker_ แสดงค่าของ feature

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],s=10*df['SepalLength'],c=df2['Name'],alpha=0.5)

# %% [markdown]
# ## ตัวแปร Marker ใช้ในการเปลี่ยนหน้าตาของ marker

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],s=100,c=df2['Name'],alpha=0.5,marker='$f$')

# %% [markdown]
# ## การ plot กราฟหลายๆอันซ้อนกัน

# %%
plt.scatter(df['PetalLength'][:50],df['PetalWidth'][:50],s=100,c='m',alpha=0.5,marker='$A$')
plt.scatter(df['PetalLength'][50:100],df['PetalWidth'][50:100],s=100,c='c',alpha=0.5,marker='$B$')
plt.scatter(df['PetalLength'][100:],df['PetalWidth'][100:],s=100,c='r',alpha=0.5,marker='$C$')

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'or',alpha=0.5)
plt.plot(df['PetalLength'][50:100],df['PetalWidth'][50:100],'xc',alpha=0.5)
plt.plot(df['PetalLength'][100:],df['PetalWidth'][100:],'*m',alpha=0.5)

# %% [markdown]
# # Label-Legend
# plt.plot() input ตัวที่ 3 คือตัวกำหนดหน้าตาของ Marker
#
# 'หน้าตาMarker'-'ตามด้วยลักษณะของเส้นเชื่อมจุด'-'สี'

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'or',alpha=0.5)

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'o-r',alpha=0.5) #ตัว marker เป็น o เส้นเชื่อระหว่างจุดเป็นขีด

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'o:r',alpha=0.5) #ตัว marker เป็น o เส้นเชื่อระหว่างจุดเป็นจุด

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'or',alpha=0.5,label = 'setosa')
plt.plot(df['PetalLength'][50:100],df['PetalWidth'][50:100],'xc',alpha=0.5,label = 'versicolor')
plt.plot(df['PetalLength'][100:],df['PetalWidth'][100:],'*m',alpha=0.5,label = 'virginica')
plt.legend(loc='lower right') #สามารถเพิ่ม location ได้ หรือไม่ต้องใส่อะไรเลยก็ได้ โดยให้ label ที่ใส่อยู่ในที่ต่างๆ 
plt.title('iris flower data distribution'); #ตั้งชื่อกราฟโดยใช้ .title
plt.xlabel('PetalLength'); ##ชื่อแกน x 
plt.ylabel('PetalWidth'); ##ชื่อแกน y (ใส่ ; เพื่อไม่ให้ตัวหนังสือทับกับกราฟ ต้องใส่ลงไปหลังคำสั่งต่างๆ)

# %% [markdown]
# # 3D Sactter

# %%
ax = plt.axes(projection ="3d")
ax.scatter3D(df['PetalLength'],df['PetalWidth'],df['SepalWidth'],c=df2['Name'])

# %% [markdown]
# # Bubble Chart
#
# scatter plot ที่ใช้ขนาดของ marker ในการสื่อปริมาณของข้อมูล

# %%
plt.scatter(df['PetalLength'][100:],df['PetalWidth'][100:],s=180*df['SepalWidth'][100:],c='r')

# %% [markdown]
# # Example

# %%
import pandas as pd

# %%
from google.colab import drive #เชื่อมต่อ google.colab กับ drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os #ทำงานเกี่ยวกับการจัดการไฟล์ 
path = '/content/drive/My Drive/dataviz_2021_data'

# %%
data_path = os.path.join(path,'passenger-covid19.xls')

# %%
data_covid = pd.read_excel(os.path.join(path,'passenger-covid19.xlsx'),sheet_name='Data63-64')
data_covid
# Out:
#    ขนคน/ขนสินค้า โหมดการเดินทาง  ... 2021-03-13 00:00:00 2021-03-14 00:00:00
# 0      ขนคน (คน)          ทางบก  ...             51204.0             58371.0
# 1      ขนคน (คน)          ทางบก  ...                 NaN                 NaN
# 2      ขนคน (คน)          ทางบก  ...             11373.0             12455.0
# 3     ขนคน (คัน)          ทางบก  ...            940739.0            870772.0
# 4     ขนคน (คัน)          ทางบก  ...           1348121.0           1211478.0
# 5     ขนคน (คัน)          ทางบก  ...           1305116.0           1192083.0
# 6     ขนคน (คัน)          ทางบก  ...           1090319.0           1045273.0
# 7     ขนคน (คัน)          ทางบก  ...                 NaN                 NaN
# 8      ขนคน (คน)          ทางบก  ...              3629.0              3798.0
# 9      ขนคน (คน)          ทางบก  ...                 NaN                 NaN
# 10     ขนคน (คน)          ทางบก  ...            632056.0            565401.0
# 11     ขนคน (คน)          ทางบก  ...            116540.0            114120.0
# 12     ขนคน (คน)          ทางบก  ...                 NaN                 NaN
# 13    ขนคน (คัน)          ทางบก  ...                 NaN                 NaN
# 14    ขนคน (คัน)          ทางบก  ...                 NaN                 NaN
# 15     ขนคน (คน)         ทางน้ำ  ...                 NaN                 NaN
# 16     ขนคน (คน)         ทางน้ำ  ...              4625.0              4465.0
# 17     ขนคน (คน)         ทางน้ำ  ...              5630.0              5492.0
# 18     ขนคน (คน)         ทางน้ำ  ...             83864.0             63281.0
# 19     ขนคน (คน)         ทางน้ำ  ...                 NaN                 NaN
# 20     ขนคน (คน)         ทางราง  ...             33789.0             36116.0
# 21     ขนคน (คน)         ทางราง  ...            182202.0            138595.0
# 22     ขนคน (คน)         ทางราง  ...             24597.0             18998.0
# 23     ขนคน (คน)         ทางราง  ...             30258.0             26125.0
# 24     ขนคน (คน)         ทางราง  ...            410743.0            326242.0
# 25     ขนคน (คน)       ทางอากาศ  ...             12038.0             11299.0
# 26     ขนคน (คน)       ทางอากาศ  ...             14804.0             14751.0
# 27     ขนคน (คน)       ทางอากาศ  ...             12543.0             17277.0
# 28     ขนคน (คน)       ทางอากาศ  ...             11486.0             15154.0
# 29     ขนคน (คน)         ทางถนน  ...                 NaN                 NaN
# 30     ขนคน (คน)         ทางถนน  ...                 NaN                 NaN
# 31     ขนคน (คน)         ทางราง  ...                 NaN                 NaN
# 32     ขนคน (คน)         ทางราง  ...                 NaN                 NaN
# 33     ขนคน (คน)         ทางน้ำ  ...                 9.0                 6.0
# 34     ขนคน (คน)         ทางน้ำ  ...                 0.0                 0.0
# 35     ขนคน (คน)       ทางอากาศ  ...              1009.0               815.0
# 36     ขนคน (คน)       ทางอากาศ  ...               791.0              1100.0
# 37     ขนคน (คน)       ทางอากาศ  ...                 0.0                 0.0
# 38     ขนคน (คน)       ทางอากาศ  ...                 3.0                 1.0
# 39     ขนคน (คน)       ทางอากาศ  ...                 0.0                14.0
# 40     ขนคน (คน)       ทางอากาศ  ...                 0.0                 3.0
# 41     ขนคน (คน)       ทางอากาศ  ...                 0.0                 0.0
# 42     ขนคน (คน)       ทางอากาศ  ...                 0.0                 0.0
#
# [43 rows x 445 columns]

# %%
data_drop = data_covid.dropna()
data_drop
# Out:
#    ขนคน/ขนสินค้า โหมดการเดินทาง  ... 2021-03-13 00:00:00 2021-03-14 00:00:00
# 0      ขนคน (คน)          ทางบก  ...             51204.0             58371.0
# 3     ขนคน (คัน)          ทางบก  ...            940739.0            870772.0
# 4     ขนคน (คัน)          ทางบก  ...           1348121.0           1211478.0
# 5     ขนคน (คัน)          ทางบก  ...           1305116.0           1192083.0
# 6     ขนคน (คัน)          ทางบก  ...           1090319.0           1045273.0
# 10     ขนคน (คน)          ทางบก  ...            632056.0            565401.0
# 11     ขนคน (คน)          ทางบก  ...            116540.0            114120.0
# 16     ขนคน (คน)         ทางน้ำ  ...              4625.0              4465.0
# 17     ขนคน (คน)         ทางน้ำ  ...              5630.0              5492.0
# 18     ขนคน (คน)         ทางน้ำ  ...             83864.0             63281.0
# 20     ขนคน (คน)         ทางราง  ...             33789.0             36116.0
# 21     ขนคน (คน)         ทางราง  ...            182202.0            138595.0
# 22     ขนคน (คน)         ทางราง  ...             24597.0             18998.0
# 23     ขนคน (คน)         ทางราง  ...             30258.0             26125.0
# 24     ขนคน (คน)         ทางราง  ...            410743.0            326242.0
# 25     ขนคน (คน)       ทางอากาศ  ...             12038.0             11299.0
# 26     ขนคน (คน)       ทางอากาศ  ...             14804.0             14751.0
# 27     ขนคน (คน)       ทางอากาศ  ...             12543.0             17277.0
# 28     ขนคน (คน)       ทางอากาศ  ...             11486.0             15154.0
# 35     ขนคน (คน)       ทางอากาศ  ...              1009.0               815.0
# 36     ขนคน (คน)       ทางอากาศ  ...               791.0              1100.0
# 37     ขนคน (คน)       ทางอากาศ  ...                 0.0                 0.0
# 38     ขนคน (คน)       ทางอากาศ  ...                 3.0                 1.0
# 39     ขนคน (คน)       ทางอากาศ  ...                 0.0                14.0
# 40     ขนคน (คน)       ทางอากาศ  ...                 0.0                 3.0
# 41     ขนคน (คน)       ทางอากาศ  ...                 0.0                 0.0
# 42     ขนคน (คน)       ทางอากาศ  ...                 0.0                 0.0
#
# [27 rows x 445 columns]

# %%
data_drop.iloc[:3,6]
# Out:
# 0     233330
# 3     977347
# 4    1072314
# Name: 2020-01-01 00:00:00, dtype: object

# %%
plt.scatter([0,100,200],[200,200,200],s=[200,3000,700])

# %%
import numpy as np
import matplotlib

# %%
0.001*data_drop.iloc[:3,6]
# Out:
# 0     233.33
# 3    977.347
# 4    1072.31
# Name: 2020-01-01 00:00:00, dtype: object

# %%
matplotlib.rcParams['figure.figsize']=[8,5]

# %%
plt.scatter([0,100,200],[200,200,200],s=list(0.001*data_drop.iloc[:3,6]),alpha=0.5)
plt.xlim((-50,300)); #หลุดกรอบในแนวแกน x ใช้ .xlim กำหนดให้จุดอยู่ในกรอบ

# %% [markdown]
# # สร้าง list ลำดับ
#
# FG_l = list(FG) ### แปลงเป็น list
#
# FG_l.sort

# %%
data = pd.read_excel('/content/drive/MyDrive/dataviz_2021_data/passenger-covid19.xlsx')   
data

# %%
data_drop = data.dropna()
data_drop

# %%
data_travel = data_drop['รูปแบบการเดินทาง'].astype('category')
data_travel

# %%
data_travel.dtypes
# Out:
# CategoricalDtype(categories=['การเดินทางภายในจังหวัด/กรุงเทพ', 'การเดินทางระหว่างจังหวัด',
#                   'การเดินทางระหว่างประเทศ'],
#                  ordered=False)

# %%
data_travel_2 = data_travel.replace({'การเดินทางภายในจังหวัด/กรุงเทพ':'travel_inside_BKK','การเดินทางระหว่างจังหวัด':'travel_inside_PV','การเดินทางระหว่างประเทศ':'travel_inter'})
data_travel_2 .astype('category') #เปลี่ยนชื่อใหม่

# %%
data_ins = data_drop['ขนคน/ขนสินค้า'].astype('category')
data_ins

# %%
data_ins.dtypes
# Out:
# CategoricalDtype(categories=['ขนคน (คน)', 'ขนคน (คัน)'], ordered=False)

# %%
data_ins_2 = data_ins.replace({'ขนคน (คน)':'people','ขนคน (คัน)':'rod'})
data_ins_2 .astype('category') #เปลี่ยนชื่อใหม่

# %%
import matplotlib

# %%
matplotlib.rcParams['figure.figsize']=[8,8] # เพิ่มขนาดกราฟ

# %%
plt.scatter(data_travel_2,data_ins_2 ,s=0.0001*data_drop['มี.ค. 2562'],alpha=0.5)
plt.xlabel('Travel mode') #ชื่อแกน X
plt.ylabel('People / Rod'); #ชื่อแกน Y
plt.xlim((-1,4)) #ปรับแกน X 
plt.ylim((-1,2)) #ปรับแกน Y
# Out:
# (-1.0, 2.0)

# %% [markdown]
# # Boxplot

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
O = plt.boxplot(df['SepalWidth'])

# %%
O
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fa6139b0990>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fa6139b3950>,
#   <matplotlib.lines.Line2D at 0x7fa6139b3e90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fa6139bb990>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fa6139bb450>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fa6139b0e90>,
#   <matplotlib.lines.Line2D at 0x7fa6139b3410>]}

# %%
O['fliers'][0].get_ydata() # .get_ydata ดึงค่าออกมา
# Out:
# array([2. , 4.4, 4.1, 4.2])

# %%
O = plt.boxplot(df['SepalWidth'],showmeans=True,meanline=True)

# %%
O
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fa613a6b410>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fa613b552d0>,
#   <matplotlib.lines.Line2D at 0x7fa613ae0e10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fa613a79110>],
#  'means': [<matplotlib.lines.Line2D at 0x7fa613ae03d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fa613ae0790>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fa613a6bd90>,
#   <matplotlib.lines.Line2D at 0x7fa613a6bb90>]}

# %%
O = plt.boxplot(df['SepalWidth'],showmeans=True,meanline=True,vert=False)

# %%
from matplotlib import pyplot as plt

# %%
o = plt.boxplot(df['SepalWidth'],showmeans=True,meanline=True,vert=False)

# %% [markdown]
# # เปรียบเทียบข้อมูล boxplot ของดอกไม้หลายๆชนิด

# %%
o = plt.boxplot(df['SepalWidth'],showmeans=True,meanline=True)
